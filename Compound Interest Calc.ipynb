# %% [markdown]
# # Comound Interest Calculator
# ## Run to Start Inputs

# %%
from IPython.display import Math
Math('A=P(1+r/n)^nt')
# Out:
# $\displaystyle A=P(1+r/n)^nt$

# %%
#Compund Interest Formula

# P = Initial Principal Balance
P = input('Initial Principal Balance ($): ')
P = int(P)

# r = Interest Rate
r = input('Interest Rate to the 1/100th: ')
r = float(r)

# n = Number of times Interest applied per time period
n = input('Number of times Interest applied per time period: ')
n = int(n)

# t = Number of time periods elasped
t = input('Number of time periods elapsed: ')
t = int(t)

# A = Final Amount
A = P*(1+(r/n))**(n*t)
A = round(A,2)
print('Final Amount: ' + str(A))
# Out:
# Initial Principal Balance ($): 35000
# Interest Rate to the 1/100th: .05
# Number of times Interest applied per time period: 2
# Number of time periods elapsed: 10
# Final Amount: 57351.58

# %%
from ipywidgets import interact, widgets

def AdjustP(P):
    return P

def Adjustr(r):
    r = r*.01
    return r

def Adjustn(n):
    return n

def Adjustt(t):
    return t

def AdjustedFinalAmount (A):
    A = P*(1+(r/n))**(n*t)
    return (round(A,2))
interact(AdjustP,P=widgets.IntSlider(min=0,max=100000,value=P))
interact(Adjustr,r=widgets.IntSlider(min=0,max=100,value=r))
interact(Adjustn,n=widgets.IntSlider(min=0,max=100,value=n))
interact(Adjustt,t=widgets.IntSlider(min=0,max=100,value=t))
print(A)
# Out:
# interactive(children=(IntSlider(value=35000, description='P', max=100000), Output()), _dom_classes=('widget-in…
# interactive(children=(IntSlider(value=0, description='r'), Output()), _dom_classes=('widget-interact',))
# interactive(children=(IntSlider(value=2, description='n'), Output()), _dom_classes=('widget-interact',))
# interactive(children=(IntSlider(value=10, description='t'), Output()), _dom_classes=('widget-interact',))
# 57351.58
